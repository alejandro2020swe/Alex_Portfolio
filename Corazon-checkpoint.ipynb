# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('corazon.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0      172              N      0.0       Up             0
# 1      156              N      1.0     Flat             1
# 2       98              N      0.0       Up             0
# 3      108              Y      1.5     Flat             1
# 4      122              N      0.0       Up             0
# ..     ...            ...      ...      ...           ...
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0
#
# [918 rows x 12 columns]

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
sns.heatmap(df.describe())
# Out:
# <AxesSubplot:>

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %%
df.corr()
# Out:
#                    Age  RestingBP  Cholesterol  FastingBS     MaxHR   Oldpeak  \
# Age           1.000000   0.254399    -0.095282   0.198039 -0.382045  0.258612
# RestingBP     0.254399   1.000000     0.100893   0.070193 -0.112135  0.164803
# Cholesterol  -0.095282   0.100893     1.000000  -0.260974  0.235792  0.050148
# FastingBS     0.198039   0.070193    -0.260974   1.000000 -0.131438  0.052698
# MaxHR        -0.382045  -0.112135     0.235792  -0.131438  1.000000 -0.160691
# Oldpeak       0.258612   0.164803     0.050148   0.052698 -0.160691  1.000000
# HeartDisease  0.282039   0.107589    -0.232741   0.267291 -0.400421  0.403951
#
#               HeartDisease
# Age               0.282039
# RestingBP         0.107589
# Cholesterol      -0.232741
# FastingBS         0.267291
# MaxHR            -0.400421
# Oldpeak           0.403951
# HeartDisease      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# <AxesSubplot:>

# %%
df['Age']
# Out:
# 0      40
# 1      49
# 2      37
# 3      48
# 4      54
#        ..
# 913    45
# 914    68
# 915    57
# 916    57
# 917    38
# Name: Age, Length: 918, dtype: int64

# %%
sns.set(rc = {'figure.figsize':(19,8)})
sns.set_context("talk", font_scale=1)
sns.countplot(x=df['Age'],data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
df['Age'].min()
# Out:
# 28

# %%
df['Age'].mean()
# Out:
# 53.510893246187365

# %%
df['Age'].max()
# Out:
# 77

# %%
sns.countplot(x=df['Sex'],palette='rocket')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
df['Sex'].value_counts()
# Out:
# M    725
# F    193
# Name: Sex, dtype: int64

# %%
df['ChestPainType'].value_counts()
# Out:
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: ChestPainType, dtype: int64

# %%
sns.countplot(x=df['ChestPainType'],palette='deep')
# Out:
# <AxesSubplot:xlabel='ChestPainType', ylabel='count'>

# %%
df['RestingBP'].mean()
# Out:
# 132.39651416122004

# %%
df['RestingBP'].min()
# Out:
# 0

# %%
df['RestingBP'].max()
# Out:
# 200

# %%
sns.set(rc = {'figure.figsize':(19,10)})
sns.set_context("talk", font_scale=0.6)
sns.countplot(x=df['RestingBP'],data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='RestingBP', ylabel='count'>

# %%
df[df['RestingBP']==0]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 449   55   M           NAP          0            0          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 449    155              N      1.5     Flat             1

# %%
df['Cholesterol'].mean()
# Out:
# 198.7995642701525

# %%
df['Cholesterol'].min()
# Out:
# 0

# %%
df['Cholesterol'].max()
# Out:
# 603

# %%
sns.set(rc = {'figure.figsize':(19,10)})
sns.set_context("talk", font_scale=0.6)
sns.(x=df['Cholesterol'],data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Cholesterol', ylabel='count'>

# %%
sns.set(rc = {'figure.figsize':(19,10)})
sns.set_context("talk", font_scale=0.6)
plt.pie(x=df['Cholesterol'],data=df)
# Out:
# ([<matplotlib.patches.Wedge at 0x18650c2dac0>,
#   <matplotlib.patches.Wedge at 0x186518dac40>,
#   <matplotlib.patches.Wedge at 0x186518dafd0>,
#   <matplotlib.patches.Wedge at 0x18650c977c0>,
#   <matplotlib.patches.Wedge at 0x18650c97eb0>,
#   <matplotlib.patches.Wedge at 0x18650c97f40>,
#   <matplotlib.patches.Wedge at 0x1864febff10>,
#   <matplotlib.patches.Wedge at 0x1864fdb8730>,
#   <matplotlib.patches.Wedge at 0x18651909a90>,
#   <matplotlib.patches.Wedge at 0x186519095b0>,
#   <matplotlib.patches.Wedge at 0x18651780880>,
#   <matplotlib.patches.Wedge at 0x1865190a070>,
#   <matplotlib.patches.Wedge at 0x1865190a460>,
#   <matplotlib.patches.Wedge at 0x186518d6880>,
#   <matplotlib.patches.Wedge at 0x18650b90df0>,
#   <matplotlib.patches.Wedge at 0x18650b906a0>,
#   <matplotlib.patches.Wedge at 0x18650b90c70>,
#   <matplotlib.patches.Wedge at 0x1864fdc7580>,
#   <matplotlib.patches.Wedge at 0x1864fdc7b20>,
#   <matplotlib.patches.Wedge at 0x18650c9c280>,
#   <matplotlib.patches.Wedge at 0x18650c9c0a0>,
#   <matplotlib.patches.Wedge at 0x18650c9cdc0>,
#   <matplotlib.patches.Wedge at 0x18650b73f40>,
#   <matplotlib.patches.Wedge at 0x18650b73dc0>,
#   <matplotlib.patches.Wedge at 0x18650b73400>,
#   <matplotlib.patches.Wedge at 0x186518d7910>,
#   <matplotlib.patches.Wedge at 0x186518d78e0>,
#   <matplotlib.patches.Wedge at 0x186518d7e80>,
#   <matplotlib.patches.Wedge at 0x18650b76670>,
#   <matplotlib.patches.Wedge at 0x18650b763a0>,
#   <matplotlib.patches.Wedge at 0x186518f0d30>,
#   <matplotlib.patches.Wedge at 0x186518f0700>,
#   <matplotlib.patches.Wedge at 0x186518f01f0>,
#   <matplotlib.patches.Wedge at 0x186518f0430>,
#   <matplotlib.patches.Wedge at 0x18650dd40d0>,
#   <matplotlib.patches.Wedge at 0x18650c27940>,
#   <matplotlib.patches.Wedge at 0x18650c2d340>,
#   <matplotlib.patches.Wedge at 0x1864ff13460>,
#   <matplotlib.patches.Wedge at 0x1864fe36f10>,
#   <matplotlib.patches.Wedge at 0x1864f9b7550>,
#   <matplotlib.patches.Wedge at 0x1864febfaf0>,
#   <matplotlib.patches.Wedge at 0x1864febf490>,
#   <matplotlib.patches.Wedge at 0x1864f2d53a0>,
#   <matplotlib.patches.Wedge at 0x1864fcab2e0>,
#   <matplotlib.patches.Wedge at 0x1864fcaba60>,
#   <matplotlib.patches.Wedge at 0x1864f3e6430>,
#   <matplotlib.patches.Wedge at 0x1864f9877f0>,
#   <matplotlib.patches.Wedge at 0x1864f9877c0>,
#   <matplotlib.patches.Wedge at 0x1864fcc1820>,
#   <matplotlib.patches.Wedge at 0x1864fd106a0>,
#   <matplotlib.patches.Wedge at 0x1864f871220>,
#   <matplotlib.patches.Wedge at 0x1864fcc8d00>,
#   <matplotlib.patches.Wedge at 0x1864fe7ffd0>,
#   <matplotlib.patches.Wedge at 0x1864f937310>,
#   <matplotlib.patches.Wedge at 0x1864fd99370>,
#   <matplotlib.patches.Wedge at 0x1864fd99670>,
#   <matplotlib.patches.Wedge at 0x1864f492790>,
#   <matplotlib.patches.Wedge at 0x1864f492d00>,
#   <matplotlib.patches.Wedge at 0x1864fcbfbe0>,
#   <matplotlib.patches.Wedge at 0x1864ff6ed60>,
#   <matplotlib.patches.Wedge at 0x1864fe0c130>,
#   <matplotlib.patches.Wedge at 0x1864ba21760>,
#   <matplotlib.patches.Wedge at 0x1864ffa5940>,
#   <matplotlib.patches.Wedge at 0x1864b1b1eb0>,
#   <matplotlib.patches.Wedge at 0x1864f9db940>,
#   <matplotlib.patches.Wedge at 0x1864f9dbe80>,
#   <matplotlib.patches.Wedge at 0x1864e0460d0>,
#   <matplotlib.patches.Wedge at 0x1864fa3d3a0>,
#   <matplotlib.patches.Wedge at 0x186519d0d90>,
#   <matplotlib.patches.Wedge at 0x186519d0820>,
#   <matplotlib.patches.Wedge at 0x1864fef70a0>,
#   <matplotlib.patches.Wedge at 0x1864fef7e20>,
#   <matplotlib.patches.Wedge at 0x1864fef7c70>,
#   <matplotlib.patches.Wedge at 0x1864f9b76d0>,
#   <matplotlib.patches.Wedge at 0x1864f9b7280>,
#   <matplotlib.patches.Wedge at 0x1864f9cb2e0>,
#   <matplotlib.patches.Wedge at 0x1864f9cb8e0>,
#   <matplotlib.patches.Wedge at 0x1864f9d9370>,
#   <matplotlib.patches.Wedge at 0x1864f9d92e0>,
#   <matplotlib.patches.Wedge at 0x1864f9d9c70>,
#   <matplotlib.patches.Wedge at 0x1864ff95c70>,
#   <matplotlib.patches.Wedge at 0x1864fe9a8e0>,
#   <matplotlib.patches.Wedge at 0x1864fe9a2b0>,
#   <matplotlib.patches.Wedge at 0x1864fe9af70>,
#   <matplotlib.patches.Wedge at 0x1864fcc55e0>,
#   <matplotlib.patches.Wedge at 0x1864fcc58e0>,
#   <matplotlib.patches.Wedge at 0x1864fcc5fa0>,
#   <matplotlib.patches.Wedge at 0x1864fcc5af0>,
#   <matplotlib.patches.Wedge at 0x1864f9ba640>,
#   <matplotlib.patches.Wedge at 0x1864f9baeb0>,
#   <matplotlib.patches.Wedge at 0x1864f9fe5b0>,
#   <matplotlib.patches.Wedge at 0x1864ffa6d60>,
#   <matplotlib.patches.Wedge at 0x1864ffa6b20>,
#   <matplotlib.patches.Wedge at 0x1864f9e87f0>,
#   <matplotlib.patches.Wedge at 0x1864f9e88e0>,
#   <matplotlib.patches.Wedge at 0x1864f9e89d0>,
#   <matplotlib.patches.Wedge at 0x1864f8ac7c0>,
#   <matplotlib.patches.Wedge at 0x1864f9a9b20>,
#   <matplotlib.patches.Wedge at 0x1864fe018e0>,
#   <matplotlib.patches.Wedge at 0x1864ffd3460>,
#   <matplotlib.patches.Wedge at 0x1864ffd36a0>,
#   <matplotlib.patches.Wedge at 0x1864f9a8160>,
#   <matplotlib.patches.Wedge at 0x1864f9a83d0>,
#   <matplotlib.patches.Wedge at 0x1864f9addc0>,
#   <matplotlib.patches.Wedge at 0x1864fe74490>,
#   <matplotlib.patches.Wedge at 0x1864fe744c0>,
#   <matplotlib.patches.Wedge at 0x1864f45d4f0>,
#   <matplotlib.patches.Wedge at 0x1864fa373d0>,
#   <matplotlib.patches.Wedge at 0x1864f342f40>,
#   <matplotlib.patches.Wedge at 0x186519150a0>,
#   <matplotlib.patches.Wedge at 0x18651915700>,
#   <matplotlib.patches.Wedge at 0x18651915430>,
#   <matplotlib.patches.Wedge at 0x18650b73280>,
#   <matplotlib.patches.Wedge at 0x18650ea6ca0>,
#   <matplotlib.patches.Wedge at 0x18650ea6370>,
#   <matplotlib.patches.Wedge at 0x18650bf17f0>,
#   <matplotlib.patches.Wedge at 0x1864f9ef220>,
#   <matplotlib.patches.Wedge at 0x1864fd809d0>,
#   <matplotlib.patches.Wedge at 0x18650c2daf0>,
#   <matplotlib.patches.Wedge at 0x1864fdad0d0>,
#   <matplotlib.patches.Wedge at 0x1864de5cfa0>,
#   <matplotlib.patches.Wedge at 0x1864fe10100>,
#   <matplotlib.patches.Wedge at 0x1864fd88ca0>,
#   <matplotlib.patches.Wedge at 0x1864ffbc4f0>,
#   <matplotlib.patches.Wedge at 0x1864ffbc640>,
#   <matplotlib.patches.Wedge at 0x1864fc90e20>,
#   <matplotlib.patches.Wedge at 0x1864fc90730>,
#   <matplotlib.patches.Wedge at 0x1864fcb4be0>,
#   <matplotlib.patches.Wedge at 0x1864fea4850>,
#   <matplotlib.patches.Wedge at 0x1864fea44c0>,
#   <matplotlib.patches.Wedge at 0x1864fea4a60>,
#   <matplotlib.patches.Wedge at 0x1864fea4f40>,
#   <matplotlib.patches.Wedge at 0x1864fe85ca0>,
#   <matplotlib.patches.Wedge at 0x18650182460>,
#   <matplotlib.patches.Wedge at 0x186519d77c0>,
#   <matplotlib.patches.Wedge at 0x186519d7250>,
#   <matplotlib.patches.Wedge at 0x186519d7280>,
#   <matplotlib.patches.Wedge at 0x1865184e6d0>,
#   <matplotlib.patches.Wedge at 0x1865184ea60>,
#   <matplotlib.patches.Wedge at 0x1865184e160>,
#   <matplotlib.patches.Wedge at 0x1865184e700>,
#   <matplotlib.patches.Wedge at 0x186516e15e0>,
#   <matplotlib.patches.Wedge at 0x186516e1190>,
#   <matplotlib.patches.Wedge at 0x186516e1280>,
#   <matplotlib.patches.Wedge at 0x18651a0ef40>,
#   <matplotlib.patches.Wedge at 0x18651a0ee50>,
#   <matplotlib.patches.Wedge at 0x1864fdbc7f0>,
#   <matplotlib.patches.Wedge at 0x1864fe48a90>,
#   <matplotlib.patches.Wedge at 0x18650dc7b50>,
#   <matplotlib.patches.Wedge at 0x1864d4f7ac0>,
#   <matplotlib.patches.Wedge at 0x1864bc8a400>,
#   <matplotlib.patches.Wedge at 0x1864f458c40>,
#   <matplotlib.patches.Wedge at 0x1864c112310>,
#   <matplotlib.patches.Wedge at 0x1864f847190>,
#   <matplotlib.patches.Wedge at 0x1864f8987c0>,
#   <matplotlib.patches.Wedge at 0x1864f9dd880>,
#   <matplotlib.patches.Wedge at 0x1864f9dd520>,
#   <matplotlib.patches.Wedge at 0x1864f9ddf40>,
#   <matplotlib.patches.Wedge at 0x18644fdb640>,
#   <matplotlib.patches.Wedge at 0x18650ebdeb0>,
#   <matplotlib.patches.Wedge at 0x1864f7499a0>,
#   <matplotlib.patches.Wedge at 0x1864f7614c0>,
#   <matplotlib.patches.Wedge at 0x1864feaf6a0>,
#   <matplotlib.patches.Wedge at 0x18651a0c7c0>,
#   <matplotlib.patches.Wedge at 0x186517363d0>,
#   <matplotlib.patches.Wedge at 0x1864f991370>,
#   <matplotlib.patches.Wedge at 0x1864f787e80>,
#   <matplotlib.patches.Wedge at 0x18650b90040>,
#   <matplotlib.patches.Wedge at 0x18650b76cd0>,
#   <matplotlib.patches.Wedge at 0x186518d7340>,
#   <matplotlib.patches.Wedge at 0x186518d6cd0>,
#   <matplotlib.patches.Wedge at 0x186518d6610>,
#   <matplotlib.patches.Wedge at 0x186518d6a30>,
#   <matplotlib.patches.Wedge at 0x1865190aac0>,
#   <matplotlib.patches.Wedge at 0x1865190acd0>,
#   <matplotlib.patches.Wedge at 0x186518da880>,
#   <matplotlib.patches.Wedge at 0x18650c97730>,
#   <matplotlib.patches.Wedge at 0x1865178d610>,
#   <matplotlib.patches.Wedge at 0x1865195bf70>,
#   <matplotlib.patches.Wedge at 0x1865195b9a0>,
#   <matplotlib.patches.Wedge at 0x1865195b430>,
#   <matplotlib.patches.Wedge at 0x18651780bb0>,
#   <matplotlib.patches.Wedge at 0x18651780250>,
#   <matplotlib.patches.Wedge at 0x18651780100>,
#   <matplotlib.patches.Wedge at 0x1865174b2e0>,
#   <matplotlib.patches.Wedge at 0x1865174d250>,
#   <matplotlib.patches.Wedge at 0x1864fd75b80>,
#   <matplotlib.patches.Wedge at 0x1864fcb3100>,
#   <matplotlib.patches.Wedge at 0x18650c274c0>,
#   <matplotlib.patches.Wedge at 0x18650c27850>,
#   <matplotlib.patches.Wedge at 0x1864de379d0>,
#   <matplotlib.patches.Wedge at 0x18650c21670>,
#   <matplotlib.patches.Wedge at 0x18650f12880>,
#   <matplotlib.patches.Wedge at 0x18651811430>,
#   <matplotlib.patches.Wedge at 0x18651811940>,
#   <matplotlib.patches.Wedge at 0x18651811fa0>,
#   <matplotlib.patches.Wedge at 0x18651811d90>,
#   <matplotlib.patches.Wedge at 0x186519a56a0>,
#   <matplotlib.patches.Wedge at 0x186519a5280>,
#   <matplotlib.patches.Wedge at 0x186519a5c70>,
#   <matplotlib.patches.Wedge at 0x186519b9040>,
#   <matplotlib.patches.Wedge at 0x186519b9280>,
#   <matplotlib.patches.Wedge at 0x186519b96d0>,
#   <matplotlib.patches.Wedge at 0x186519a11f0>,
#   <matplotlib.patches.Wedge at 0x186519a16a0>,
#   <matplotlib.patches.Wedge at 0x186519a1f40>,
#   <matplotlib.patches.Wedge at 0x186519a1760>,
#   <matplotlib.patches.Wedge at 0x1865170df40>,
#   <matplotlib.patches.Wedge at 0x1865170d940>,
#   <matplotlib.patches.Wedge at 0x18650d345b0>,
#   <matplotlib.patches.Wedge at 0x18650d4a430>,
#   <matplotlib.patches.Wedge at 0x18650d4aa60>,
#   <matplotlib.patches.Wedge at 0x18650d4a070>,
#   <matplotlib.patches.Wedge at 0x186517aac10>,
#   <matplotlib.patches.Wedge at 0x186517aaf70>,
#   <matplotlib.patches.Wedge at 0x186517aa4f0>,
#   <matplotlib.patches.Wedge at 0x18650e8a1f0>,
#   <matplotlib.patches.Wedge at 0x18650e8c340>,
#   <matplotlib.patches.Wedge at 0x18650e8ce80>,
#   <matplotlib.patches.Wedge at 0x18650e8c550>,
#   <matplotlib.patches.Wedge at 0x18650e91220>,
#   <matplotlib.patches.Wedge at 0x18650e91910>,
#   <matplotlib.patches.Wedge at 0x18650e91850>,
#   <matplotlib.patches.Wedge at 0x186516dd100>,
#   <matplotlib.patches.Wedge at 0x1864d86aa90>,
#   <matplotlib.patches.Wedge at 0x1864d86aaf0>,
#   <matplotlib.patches.Wedge at 0x1864d86a5b0>,
#   <matplotlib.patches.Wedge at 0x186517303a0>,
#   <matplotlib.patches.Wedge at 0x18651730e80>,
#   <matplotlib.patches.Wedge at 0x18651730e20>,
#   <matplotlib.patches.Wedge at 0x1865172f640>,
#   <matplotlib.patches.Wedge at 0x1865172f070>,
#   <matplotlib.patches.Wedge at 0x186519b0850>,
#   <matplotlib.patches.Wedge at 0x186519b0f10>,
#   <matplotlib.patches.Wedge at 0x186517274c0>,
#   <matplotlib.patches.Wedge at 0x186519b4550>,
#   <matplotlib.patches.Wedge at 0x186519b4970>,
#   <matplotlib.patches.Wedge at 0x186519b46d0>,
#   <matplotlib.patches.Wedge at 0x1864d87f550>,
#   <matplotlib.patches.Wedge at 0x1864fe8a2b0>,
#   <matplotlib.patches.Wedge at 0x1864fe8a0a0>,
#   <matplotlib.patches.Wedge at 0x18650e9d3d0>,
#   <matplotlib.patches.Wedge at 0x18650e9d9a0>,
#   <matplotlib.patches.Wedge at 0x1864fcce340>,
#   <matplotlib.patches.Wedge at 0x186500a7700>,
#   <matplotlib.patches.Wedge at 0x18650f19340>,
#   <matplotlib.patches.Wedge at 0x18650f19250>,
#   <matplotlib.patches.Wedge at 0x18650f19ee0>,
#   <matplotlib.patches.Wedge at 0x1864fcb2eb0>,
#   <matplotlib.patches.Wedge at 0x1864fcb2100>,
#   <matplotlib.patches.Wedge at 0x1864fcb27c0>,
#   <matplotlib.patches.Wedge at 0x1864fcb23d0>,
#   <matplotlib.patches.Wedge at 0x1864d8617f0>,
#   <matplotlib.patches.Wedge at 0x1864d8610a0>,
#   <matplotlib.patches.Wedge at 0x1864d861a00>,
#   <matplotlib.patches.Wedge at 0x1864d861d90>,
#   <matplotlib.patches.Wedge at 0x1864f412f10>,
#   <matplotlib.patches.Wedge at 0x1864f412dc0>,
#   <matplotlib.patches.Wedge at 0x1864f412b20>,
#   <matplotlib.patches.Wedge at 0x1864d870f10>,
#   <matplotlib.patches.Wedge at 0x1864d870790>,
#   <matplotlib.patches.Wedge at 0x1864d870670>,
#   <matplotlib.patches.Wedge at 0x18650df2a60>,
#   <matplotlib.patches.Wedge at 0x18650df20a0>,
#   <matplotlib.patches.Wedge at 0x18650df2bb0>,
#   <matplotlib.patches.Wedge at 0x18650454430>,
#   <matplotlib.patches.Wedge at 0x18650454310>,
#   <matplotlib.patches.Wedge at 0x18650454820>,
#   <matplotlib.patches.Wedge at 0x1864fa178e0>,
#   <matplotlib.patches.Wedge at 0x1864fa17c70>,
#   <matplotlib.patches.Wedge at 0x1864fa17b50>,
#   <matplotlib.patches.Wedge at 0x18650c47d00>,
#   <matplotlib.patches.Wedge at 0x18650c47340>,
#   <matplotlib.patches.Wedge at 0x18650c47b80>,
#   <matplotlib.patches.Wedge at 0x1864f8b4160>,
#   <matplotlib.patches.Wedge at 0x1864f8b4c70>,
#   <matplotlib.patches.Wedge at 0x1864f8b4490>,
#   <matplotlib.patches.Wedge at 0x1864f8b4d90>,
#   <matplotlib.patches.Wedge at 0x1864de30220>,
#   <matplotlib.patches.Wedge at 0x1864de301c0>,
#   <matplotlib.patches.Wedge at 0x1864de30df0>,
#   <matplotlib.patches.Wedge at 0x18650f0f790>,
#   <matplotlib.patches.Wedge at 0x18650f0f430>,
#   <matplotlib.patches.Wedge at 0x18650f0f490>,
#   <matplotlib.patches.Wedge at 0x1864feb7640>,
#   <matplotlib.patches.Wedge at 0x1864feb7d90>,
#   <matplotlib.patches.Wedge at 0x1864feb7340>,
#   <matplotlib.patches.Wedge at 0x1864feb7b80>,
#   <matplotlib.patches.Wedge at 0x1864f9a13a0>,
#   <matplotlib.patches.Wedge at 0x1864f9a1f40>,
#   <matplotlib.patches.Wedge at 0x1864f9a1880>,
#   <matplotlib.patches.Wedge at 0x1864ff19f10>,
#   <matplotlib.patches.Wedge at 0x1864ff19700>,
#   <matplotlib.patches.Wedge at 0x1864de3ffd0>,
#   <matplotlib.patches.Wedge at 0x1864de3fdf0>,
#   <matplotlib.patches.Wedge at 0x1864de3f4c0>,
#   <matplotlib.patches.Wedge at 0x186501663d0>,
#   <matplotlib.patches.Wedge at 0x18650be2cd0>,
#   <matplotlib.patches.Wedge at 0x18650be28e0>,
#   <matplotlib.patches.Wedge at 0x18650be21f0>,
#   <matplotlib.patches.Wedge at 0x1864fd38e50>,
#   <matplotlib.patches.Wedge at 0x1864fd385e0>,
#   <matplotlib.patches.Wedge at 0x18650ddf8b0>,
#   <matplotlib.patches.Wedge at 0x18650ddf0a0>,
#   <matplotlib.patches.Wedge at 0x18650ddf550>,
#   <matplotlib.patches.Wedge at 0x1864fa302e0>,
#   <matplotlib.patches.Wedge at 0x1864fa30430>,
#   <matplotlib.patches.Wedge at 0x1864fa30280>,
#   <matplotlib.patches.Wedge at 0x1864f8215e0>,
#   <matplotlib.patches.Wedge at 0x1864fa1bb50>,
#   <matplotlib.patches.Wedge at 0x1864fa1b910>,
#   <matplotlib.patches.Wedge at 0x1864fa1bdc0>,
#   <matplotlib.patches.Wedge at 0x18650db0b50>,
#   <matplotlib.patches.Wedge at 0x18650db02e0>,
#   <matplotlib.patches.Wedge at 0x18650db0a60>,
#   <matplotlib.patches.Wedge at 0x1864fd501f0>,
#   <matplotlib.patches.Wedge at 0x1864fd500a0>,
#   <matplotlib.patches.Wedge at 0x1864fd507c0>,
#   <matplotlib.patches.Wedge at 0x1864fd55df0>,
#   <matplotlib.patches.Wedge at 0x1864fd55a00>,
#   <matplotlib.patches.Wedge at 0x1864fd55310>,
#   <matplotlib.patches.Wedge at 0x1864f43ffd0>,
#   <matplotlib.patches.Wedge at 0x1864f43fcd0>,
#   <matplotlib.patches.Wedge at 0x1864f43fbb0>,
#   <matplotlib.patches.Wedge at 0x1864f7e8730>,
#   <matplotlib.patches.Wedge at 0x1864f7e8250>,
#   <matplotlib.patches.Wedge at 0x1864ffd2dc0>,
#   <matplotlib.patches.Wedge at 0x1864fe96e50>,
#   <matplotlib.patches.Wedge at 0x18650d50a30>,
#   <matplotlib.patches.Wedge at 0x18650d502e0>,
#   <matplotlib.patches.Wedge at 0x18650d50b20>,
#   <matplotlib.patches.Wedge at 0x18650dab4c0>,
#   <matplotlib.patches.Wedge at 0x18650dab1c0>,
#   <matplotlib.patches.Wedge at 0x18650dab640>,
#   <matplotlib.patches.Wedge at 0x18650d83880>,
#   <matplotlib.patches.Wedge at 0x18650d835e0>,
#   <matplotlib.patches.Wedge at 0x18650d83c40>,
#   <matplotlib.patches.Wedge at 0x18650d83b50>,
#   <matplotlib.patches.Wedge at 0x18650489e50>,
#   <matplotlib.patches.Wedge at 0x18650489610>,
#   <matplotlib.patches.Wedge at 0x186504896a0>,
#   <matplotlib.patches.Wedge at 0x18650dae820>,
#   <matplotlib.patches.Wedge at 0x18650dae1f0>,
#   <matplotlib.patches.Wedge at 0x18650daed90>,
#   <matplotlib.patches.Wedge at 0x1864fa1f8b0>,
#   <matplotlib.patches.Wedge at 0x1864fa1f130>,
#   <matplotlib.patches.Wedge at 0x1864fa1f1f0>,
#   <matplotlib.patches.Wedge at 0x1864fa1f190>,
#   <matplotlib.patches.Wedge at 0x18650df4610>,
#   <matplotlib.patches.Wedge at 0x18650df4970>,
#   <matplotlib.patches.Wedge at 0x18650df4fa0>,
#   <matplotlib.patches.Wedge at 0x18650df9160>,
#   <matplotlib.patches.Wedge at 0x1864fa24b80>,
#   <matplotlib.patches.Wedge at 0x18650dee970>,
#   <matplotlib.patches.Wedge at 0x18650dee850>,
#   <matplotlib.patches.Wedge at 0x1864fe8b1f0>,
#   <matplotlib.patches.Wedge at 0x1864fe8b910>,
#   <matplotlib.patches.Wedge at 0x1864fe8b760>,
#   <matplotlib.patches.Wedge at 0x18650df0430>,
#   <matplotlib.patches.Wedge at 0x18650df08e0>,
#   <matplotlib.patches.Wedge at 0x18650df01c0>,
#   <matplotlib.patches.Wedge at 0x18650d7e490>,
#   <matplotlib.patches.Wedge at 0x18650d7e910>,
#   <matplotlib.patches.Wedge at 0x18650d7e190>,
#   <matplotlib.patches.Wedge at 0x186516d1a90>,
#   <matplotlib.patches.Wedge at 0x186516d1b20>,
#   <matplotlib.patches.Wedge at 0x1864fa158e0>,
#   <matplotlib.patches.Wedge at 0x1864fa159a0>,
#   <matplotlib.patches.Wedge at 0x1864fa157f0>,
#   <matplotlib.patches.Wedge at 0x18650f1edf0>,
#   <matplotlib.patches.Wedge at 0x18650f1ef40>,
#   <matplotlib.patches.Wedge at 0x18650f1e8e0>,
#   <matplotlib.patches.Wedge at 0x186517df3a0>,
#   <matplotlib.patches.Wedge at 0x186517df580>,
#   <matplotlib.patches.Wedge at 0x186517dfaf0>,
#   <matplotlib.patches.Wedge at 0x1865182e850>,
#   <matplotlib.patches.Wedge at 0x1865182e880>,
#   <matplotlib.patches.Wedge at 0x1865182e670>,
#   <matplotlib.patches.Wedge at 0x1864f41b520>,
#   <matplotlib.patches.Wedge at 0x1864f41bc70>,
#   <matplotlib.patches.Wedge at 0x18650dd6be0>,
#   <matplotlib.patches.Wedge at 0x18650dd6190>,
#   <matplotlib.patches.Wedge at 0x18650dd6550>,
#   <matplotlib.patches.Wedge at 0x18650d575e0>,
#   <matplotlib.patches.Wedge at 0x18650f1bf40>,
#   <matplotlib.patches.Wedge at 0x18650f1ba00>,
#   <matplotlib.patches.Wedge at 0x18650160d30>,
#   <matplotlib.patches.Wedge at 0x1864fcfcdf0>,
#   <matplotlib.patches.Wedge at 0x18650c03940>,
#   <matplotlib.patches.Wedge at 0x18650c03d30>,
#   <matplotlib.patches.Wedge at 0x1864f84baf0>,
#   <matplotlib.patches.Wedge at 0x1864f84bfd0>,
#   <matplotlib.patches.Wedge at 0x18650c30e20>,
#   <matplotlib.patches.Wedge at 0x18650c30760>,
#   <matplotlib.patches.Wedge at 0x18650c30dc0>,
#   <matplotlib.patches.Wedge at 0x1864fdc3850>,
#   <matplotlib.patches.Wedge at 0x1864fcf2a60>,
#   <matplotlib.patches.Wedge at 0x1864e2037c0>,
#   <matplotlib.patches.Wedge at 0x18650d5d580>,
#   <matplotlib.patches.Wedge at 0x18650d5d7c0>,
#   <matplotlib.patches.Wedge at 0x18650d5d820>,
#   <matplotlib.patches.Wedge at 0x1864f845370>,
#   <matplotlib.patches.Wedge at 0x1864ff1a8e0>,
#   <matplotlib.patches.Wedge at 0x1864ff1a8b0>,
#   <matplotlib.patches.Wedge at 0x1864f8294f0>,
#   <matplotlib.patches.Wedge at 0x18650d5b550>,
#   <matplotlib.patches.Wedge at 0x1864f526d60>,
#   <matplotlib.patches.Wedge at 0x1864f4c9340>,
#   <matplotlib.patches.Wedge at 0x1864ffa92b0>,
#   <matplotlib.patches.Wedge at 0x1864fcea0d0>,
#   <matplotlib.patches.Wedge at 0x18650ecd2e0>,
#   <matplotlib.patches.Wedge at 0x18650ecd640>,
#   <matplotlib.patches.Wedge at 0x18650ecd400>,
#   <matplotlib.patches.Wedge at 0x18650ecd760>,
#   <matplotlib.patches.Wedge at 0x1864f8b2e80>,
#   <matplotlib.patches.Wedge at 0x186500e0250>,
#   <matplotlib.patches.Wedge at 0x1864fa2b250>,
#   <matplotlib.patches.Wedge at 0x186516fcca0>,
#   <matplotlib.patches.Wedge at 0x186516fc280>,
#   <matplotlib.patches.Wedge at 0x186516fc9a0>,
#   <matplotlib.patches.Wedge at 0x1864fdb3880>,
#   <matplotlib.patches.Wedge at 0x1864f476bb0>,
#   <matplotlib.patches.Wedge at 0x1864fa18220>,
#   <matplotlib.patches.Wedge at 0x1864f3c4160>,
#   <matplotlib.patches.Wedge at 0x1864f4acee0>,
#   <matplotlib.patches.Wedge at 0x1864f4bd7c0>,
#   <matplotlib.patches.Wedge at 0x1864f4bd700>,
#   <matplotlib.patches.Wedge at 0x1864f44dd60>,
#   <matplotlib.patches.Wedge at 0x1864b9b85e0>,
#   <matplotlib.patches.Wedge at 0x1864f4cb640>,
#   <matplotlib.patches.Wedge at 0x18650dc2580>,
#   <matplotlib.patches.Wedge at 0x18650dc27c0>,
#   <matplotlib.patches.Wedge at 0x18650dc2940>,
#   <matplotlib.patches.Wedge at 0x18650dc2a90>,
#   <matplotlib.patches.Wedge at 0x1864fd6cdc0>,
#   <matplotlib.patches.Wedge at 0x1864fd6c4c0>,
#   <matplotlib.patches.Wedge at 0x1864fdc7f40>,
#   <matplotlib.patches.Wedge at 0x1864f481b80>,
#   <matplotlib.patches.Wedge at 0x1864f9ff8e0>,
#   <matplotlib.patches.Wedge at 0x18650056850>,
#   <matplotlib.patches.Wedge at 0x1864f8efe50>,
#   <matplotlib.patches.Wedge at 0x1864ff71c70>,
#   <matplotlib.patches.Wedge at 0x1864ff71a60>,
#   <matplotlib.patches.Wedge at 0x18650dc03d0>,
#   <matplotlib.patches.Wedge at 0x186501587f0>,
#   <matplotlib.patches.Wedge at 0x18650158ee0>,
#   <matplotlib.patches.Wedge at 0x18650158a00>,
#   <matplotlib.patches.Wedge at 0x1864ff9cb20>,
#   <matplotlib.patches.Wedge at 0x1864ff9c1f0>,
#   <matplotlib.patches.Wedge at 0x1864fe798b0>,
#   <matplotlib.patches.Wedge at 0x1864fe798e0>,
#   <matplotlib.patches.Wedge at 0x1864fe79580>,
#   <matplotlib.patches.Wedge at 0x1864fe796a0>,
#   <matplotlib.patches.Wedge at 0x1864f9bfa60>,
#   <matplotlib.patches.Wedge at 0x1864fa06400>,
#   <matplotlib.patches.Wedge at 0x1864fa20280>,
#   <matplotlib.patches.Wedge at 0x1864fa20be0>,
#   <matplotlib.patches.Wedge at 0x1864fa200a0>,
#   <matplotlib.patches.Wedge at 0x1864d8736d0>,
#   <matplotlib.patches.Wedge at 0x1864d873c10>,
#   <matplotlib.patches.Wedge at 0x1864d873820>,
#   <matplotlib.patches.Wedge at 0x18650e41c10>,
#   <matplotlib.patches.Wedge at 0x18650d80af0>,
#   <matplotlib.patches.Wedge at 0x18650d806d0>,
#   <matplotlib.patches.Wedge at 0x18650d80400>,
#   <matplotlib.patches.Wedge at 0x1864ff3bf70>,
#   <matplotlib.patches.Wedge at 0x1864ff3bc40>,
#   <matplotlib.patches.Wedge at 0x1864ff3beb0>,
#   <matplotlib.patches.Wedge at 0x1864f4b6640>,
#   <matplotlib.patches.Wedge at 0x1864fe88f40>,
#   <matplotlib.patches.Wedge at 0x1864fe88940>,
#   <matplotlib.patches.Wedge at 0x1864f4b49d0>,
#   <matplotlib.patches.Wedge at 0x1864f8b8610>,
#   <matplotlib.patches.Wedge at 0x1864ff0e160>,
#   <matplotlib.patches.Wedge at 0x1864f4bb580>,
#   <matplotlib.patches.Wedge at 0x186518357f0>,
#   <matplotlib.patches.Wedge at 0x18651835610>,
#   <matplotlib.patches.Wedge at 0x18651835850>,
#   <matplotlib.patches.Wedge at 0x1864febf310>,
#   <matplotlib.patches.Wedge at 0x186519f5c10>,
#   <matplotlib.patches.Wedge at 0x1864f9da5e0>,
#   <matplotlib.patches.Wedge at 0x1864fdb8b20>,
#   <matplotlib.patches.Wedge at 0x1864fd2f970>,
#   <matplotlib.patches.Wedge at 0x1864b9beb20>,
#   <matplotlib.patches.Wedge at 0x18650dd43d0>,
#   <matplotlib.patches.Wedge at 0x18650dd4610>,
#   <matplotlib.patches.Wedge at 0x1864fa0a370>,
#   <matplotlib.patches.Wedge at 0x1864fa0a100>,
#   <matplotlib.patches.Wedge at 0x1864f3dd6a0>,
#   <matplotlib.patches.Wedge at 0x186516f1e20>,
#   <matplotlib.patches.Wedge at 0x186516f1d60>,
#   <matplotlib.patches.Wedge at 0x186516f18b0>,
#   <matplotlib.patches.Wedge at 0x18650cf2e50>,
#   <matplotlib.patches.Wedge at 0x18650cf24f0>,
#   <matplotlib.patches.Wedge at 0x18650cf2820>,
#   <matplotlib.patches.Wedge at 0x18650cf2ee0>,
#   <matplotlib.patches.Wedge at 0x18650cedc10>,
#   <matplotlib.patches.Wedge at 0x18650ced310>,
#   <matplotlib.patches.Wedge at 0x18650cedcd0>,
#   <matplotlib.patches.Wedge at 0x18650bcc310>,
#   <matplotlib.patches.Wedge at 0x18650bcc790>,
#   <matplotlib.patches.Wedge at 0x18650bccc40>,
#   <matplotlib.patches.Wedge at 0x18650bccfd0>,
#   <matplotlib.patches.Wedge at 0x1865199edf0>,
#   <matplotlib.patches.Wedge at 0x1865199e130>,
#   <matplotlib.patches.Wedge at 0x1865199e550>,
#   <matplotlib.patches.Wedge at 0x18651997280>,
#   <matplotlib.patches.Wedge at 0x18651997700>,
#   <matplotlib.patches.Wedge at 0x18651997b80>,
#   <matplotlib.patches.Wedge at 0x18651997fa0>,
#   <matplotlib.patches.Wedge at 0x186519aa4c0>,
#   <matplotlib.patches.Wedge at 0x186519aa940>,
#   <matplotlib.patches.Wedge at 0x186519aadc0>,
#   <matplotlib.patches.Wedge at 0x186519c4280>,
#   <matplotlib.patches.Wedge at 0x186519c4700>,
#   <matplotlib.patches.Wedge at 0x186519c4b80>,
#   <matplotlib.patches.Wedge at 0x186519c4fa0>,
#   <matplotlib.patches.Wedge at 0x186523484c0>,
#   <matplotlib.patches.Wedge at 0x18652348940>,
#   <matplotlib.patches.Wedge at 0x18652348dc0>,
#   <matplotlib.patches.Wedge at 0x18652350280>,
#   <matplotlib.patches.Wedge at 0x18652350700>,
#   <matplotlib.patches.Wedge at 0x18652350b80>,
#   <matplotlib.patches.Wedge at 0x18652350fa0>,
#   <matplotlib.patches.Wedge at 0x1865235d4c0>,
#   <matplotlib.patches.Wedge at 0x1865235d940>,
#   <matplotlib.patches.Wedge at 0x1865235ddc0>,
#   <matplotlib.patches.Wedge at 0x18652367280>,
#   <matplotlib.patches.Wedge at 0x18652367700>,
#   <matplotlib.patches.Wedge at 0x18652367b80>,
#   <matplotlib.patches.Wedge at 0x18652367fa0>,
#   <matplotlib.patches.Wedge at 0x186523704c0>,
#   <matplotlib.patches.Wedge at 0x18652370940>,
#   <matplotlib.patches.Wedge at 0x18652370dc0>,
#   <matplotlib.patches.Wedge at 0x18652379280>,
#   <matplotlib.patches.Wedge at 0x18652379700>,
#   <matplotlib.patches.Wedge at 0x18652379b80>,
#   <matplotlib.patches.Wedge at 0x18652379fa0>,
#   <matplotlib.patches.Wedge at 0x186523854c0>,
#   <matplotlib.patches.Wedge at 0x18652385940>,
#   <matplotlib.patches.Wedge at 0x18652385dc0>,
#   <matplotlib.patches.Wedge at 0x1865238f280>,
#   <matplotlib.patches.Wedge at 0x1865238f700>,
#   <matplotlib.patches.Wedge at 0x1865238fb80>,
#   <matplotlib.patches.Wedge at 0x1865238ffa0>,
#   <matplotlib.patches.Wedge at 0x1865239a4c0>,
#   <matplotlib.patches.Wedge at 0x1865239a940>,
#   <matplotlib.patches.Wedge at 0x1865239adc0>,
#   <matplotlib.patches.Wedge at 0x186523a3280>,
#   <matplotlib.patches.Wedge at 0x186523a3700>,
#   <matplotlib.patches.Wedge at 0x186523a3b80>,
#   <matplotlib.patches.Wedge at 0x186523a3fa0>,
#   <matplotlib.patches.Wedge at 0x186523ae4c0>,
#   <matplotlib.patches.Wedge at 0x186523ae940>,
#   <matplotlib.patches.Wedge at 0x186523aedc0>,
#   <matplotlib.patches.Wedge at 0x186523b8280>,
#   <matplotlib.patches.Wedge at 0x186523b8700>,
#   <matplotlib.patches.Wedge at 0x186523b8b80>,
#   <matplotlib.patches.Wedge at 0x186523b8fa0>,
#   <matplotlib.patches.Wedge at 0x186523c34c0>,
#   <matplotlib.patches.Wedge at 0x186523c3940>,
#   <matplotlib.patches.Wedge at 0x186523c3dc0>,
#   <matplotlib.patches.Wedge at 0x186523cd280>,
#   <matplotlib.patches.Wedge at 0x186523cd700>,
#   <matplotlib.patches.Wedge at 0x186523cdb80>,
#   <matplotlib.patches.Wedge at 0x186523cdfa0>,
#   <matplotlib.patches.Wedge at 0x186523d84c0>,
#   <matplotlib.patches.Wedge at 0x186523d8940>,
#   <matplotlib.patches.Wedge at 0x186523d8dc0>,
#   <matplotlib.patches.Wedge at 0x186523e1280>,
#   <matplotlib.patches.Wedge at 0x186523e1700>,
#   <matplotlib.patches.Wedge at 0x186523e1b80>,
#   <matplotlib.patches.Wedge at 0x186523e1fa0>,
#   <matplotlib.patches.Wedge at 0x186523ec4c0>,
#   <matplotlib.patches.Wedge at 0x186523ec940>,
#   <matplotlib.patches.Wedge at 0x186523ecdc0>,
#   <matplotlib.patches.Wedge at 0x186523f6280>,
#   <matplotlib.patches.Wedge at 0x186523f6700>,
#   <matplotlib.patches.Wedge at 0x186523f6b80>,
#   <matplotlib.patches.Wedge at 0x186523f6fa0>,
#   <matplotlib.patches.Wedge at 0x186524014c0>,
#   <matplotlib.patches.Wedge at 0x18652401940>,
#   <matplotlib.patches.Wedge at 0x18652401dc0>,
#   <matplotlib.patches.Wedge at 0x1865240b280>,
#   <matplotlib.patches.Wedge at 0x1865240b700>,
#   <matplotlib.patches.Wedge at 0x1865240bb80>,
#   <matplotlib.patches.Wedge at 0x1865240bfa0>,
#   <matplotlib.patches.Wedge at 0x186524164c0>,
#   <matplotlib.patches.Wedge at 0x18652416940>,
#   <matplotlib.patches.Wedge at 0x18652416dc0>,
#   <matplotlib.patches.Wedge at 0x1865241f280>,
#   <matplotlib.patches.Wedge at 0x1865241f700>,
#   <matplotlib.patches.Wedge at 0x1865241fb80>,
#   <matplotlib.patches.Wedge at 0x1865241ffa0>,
#   <matplotlib.patches.Wedge at 0x1865242a4c0>,
#   <matplotlib.patches.Wedge at 0x1865242a940>,
#   <matplotlib.patches.Wedge at 0x1865242adc0>,
#   <matplotlib.patches.Wedge at 0x18652434280>,
#   <matplotlib.patches.Wedge at 0x18652434700>,
#   <matplotlib.patches.Wedge at 0x18652434b80>,
#   <matplotlib.patches.Wedge at 0x18652434fa0>,
#   <matplotlib.patches.Wedge at 0x1865243f4c0>,
#   <matplotlib.patches.Wedge at 0x1865243f940>,
#   <matplotlib.patches.Wedge at 0x1865243fdc0>,
#   <matplotlib.patches.Wedge at 0x18652449280>,
#   <matplotlib.patches.Wedge at 0x18652449700>,
#   <matplotlib.patches.Wedge at 0x18652449b80>,
#   <matplotlib.patches.Wedge at 0x18652449fa0>,
#   <matplotlib.patches.Wedge at 0x186524544c0>,
#   <matplotlib.patches.Wedge at 0x18652454940>,
#   <matplotlib.patches.Wedge at 0x18652454dc0>,
#   <matplotlib.patches.Wedge at 0x1865245d280>,
#   <matplotlib.patches.Wedge at 0x1865245d700>,
#   <matplotlib.patches.Wedge at 0x1865245db80>,
#   <matplotlib.patches.Wedge at 0x1865245dfa0>,
#   <matplotlib.patches.Wedge at 0x186524694c0>,
#   <matplotlib.patches.Wedge at 0x18652469940>,
#   <matplotlib.patches.Wedge at 0x18652469dc0>,
#   <matplotlib.patches.Wedge at 0x18652472280>,
#   <matplotlib.patches.Wedge at 0x18652472700>,
#   <matplotlib.patches.Wedge at 0x18652472b80>,
#   <matplotlib.patches.Wedge at 0x18652472fa0>,
#   <matplotlib.patches.Wedge at 0x1865247d4c0>,
#   <matplotlib.patches.Wedge at 0x1865247d940>,
#   <matplotlib.patches.Wedge at 0x1865247ddc0>,
#   <matplotlib.patches.Wedge at 0x18652487280>,
#   <matplotlib.patches.Wedge at 0x18652487700>,
#   <matplotlib.patches.Wedge at 0x18652487b80>,
#   <matplotlib.patches.Wedge at 0x18652487fa0>,
#   <matplotlib.patches.Wedge at 0x186524924c0>,
#   <matplotlib.patches.Wedge at 0x18652492940>,
#   <matplotlib.patches.Wedge at 0x18652492dc0>,
#   <matplotlib.patches.Wedge at 0x1865249b280>,
#   <matplotlib.patches.Wedge at 0x1865249b700>,
#   <matplotlib.patches.Wedge at 0x1865249bb80>,
#   <matplotlib.patches.Wedge at 0x1865249bfa0>,
#   <matplotlib.patches.Wedge at 0x186524a64c0>,
#   <matplotlib.patches.Wedge at 0x186524a6940>,
#   <matplotlib.patches.Wedge at 0x186524a6dc0>,
#   <matplotlib.patches.Wedge at 0x186524b1280>,
#   <matplotlib.patches.Wedge at 0x186524b1700>,
#   <matplotlib.patches.Wedge at 0x186524b1b80>,
#   <matplotlib.patches.Wedge at 0x186524b1fa0>,
#   <matplotlib.patches.Wedge at 0x186524bc4c0>,
#   <matplotlib.patches.Wedge at 0x186524bc940>,
#   <matplotlib.patches.Wedge at 0x186524bcdc0>,
#   <matplotlib.patches.Wedge at 0x186524c4280>,
#   <matplotlib.patches.Wedge at 0x186524c4700>,
#   <matplotlib.patches.Wedge at 0x186524c4b80>,
#   <matplotlib.patches.Wedge at 0x186524c4fa0>,
#   <matplotlib.patches.Wedge at 0x186524d04c0>,
#   <matplotlib.patches.Wedge at 0x186524d0940>,
#   <matplotlib.patches.Wedge at 0x186524d0dc0>,
#   <matplotlib.patches.Wedge at 0x186524da280>,
#   <matplotlib.patches.Wedge at 0x186524da700>,
#   <matplotlib.patches.Wedge at 0x186524dab80>,
#   <matplotlib.patches.Wedge at 0x186524dafa0>,
#   <matplotlib.patches.Wedge at 0x186524e44c0>,
#   <matplotlib.patches.Wedge at 0x186524e4940>,
#   <matplotlib.patches.Wedge at 0x186524e4dc0>,
#   <matplotlib.patches.Wedge at 0x186524ed280>,
#   <matplotlib.patches.Wedge at 0x186524ed700>,
#   <matplotlib.patches.Wedge at 0x186524edb80>,
#   <matplotlib.patches.Wedge at 0x186524edfa0>,
#   <matplotlib.patches.Wedge at 0x186524f84c0>,
#   <matplotlib.patches.Wedge at 0x186524f8940>,
#   <matplotlib.patches.Wedge at 0x186524f8dc0>,
#   <matplotlib.patches.Wedge at 0x18652503280>,
#   <matplotlib.patches.Wedge at 0x18652503700>,
#   <matplotlib.patches.Wedge at 0x18652503b80>,
#   <matplotlib.patches.Wedge at 0x18652503fa0>,
#   <matplotlib.patches.Wedge at 0x1865250e4c0>,
#   <matplotlib.patches.Wedge at 0x1865250e940>,
#   <matplotlib.patches.Wedge at 0x1865250edc0>,
#   <matplotlib.patches.Wedge at 0x18652516280>,
#   <matplotlib.patches.Wedge at 0x18652516700>,
#   <matplotlib.patches.Wedge at 0x18652516b80>,
#   <matplotlib.patches.Wedge at 0x18652516fa0>,
#   <matplotlib.patches.Wedge at 0x186525214c0>,
#   <matplotlib.patches.Wedge at 0x18652521940>,
#   <matplotlib.patches.Wedge at 0x18652521dc0>,
#   <matplotlib.patches.Wedge at 0x1865252c280>,
#   <matplotlib.patches.Wedge at 0x1865252c700>,
#   <matplotlib.patches.Wedge at 0x1865252cb80>,
#   <matplotlib.patches.Wedge at 0x1865252cfa0>,
#   <matplotlib.patches.Wedge at 0x186525374c0>,
#   <matplotlib.patches.Wedge at 0x18652537940>,
#   <matplotlib.patches.Wedge at 0x18652537dc0>,
#   <matplotlib.patches.Wedge at 0x18652540280>,
#   <matplotlib.patches.Wedge at 0x18652540700>,
#   <matplotlib.patches.Wedge at 0x18652540b80>,
#   <matplotlib.patches.Wedge at 0x18652540fa0>,
#   <matplotlib.patches.Wedge at 0x1865254a4c0>,
#   <matplotlib.patches.Wedge at 0x1865254a940>,
#   <matplotlib.patches.Wedge at 0x1865254adc0>,
#   <matplotlib.patches.Wedge at 0x18652555280>,
#   <matplotlib.patches.Wedge at 0x18652555700>,
#   <matplotlib.patches.Wedge at 0x18652555b80>,
#   <matplotlib.patches.Wedge at 0x18652555fa0>,
#   <matplotlib.patches.Wedge at 0x186525604c0>,
#   <matplotlib.patches.Wedge at 0x18652560940>,
#   <matplotlib.patches.Wedge at 0x18652560dc0>,
#   <matplotlib.patches.Wedge at 0x18652569280>,
#   <matplotlib.patches.Wedge at 0x18652569700>,
#   <matplotlib.patches.Wedge at 0x18652569b80>,
#   <matplotlib.patches.Wedge at 0x18652569fa0>,
#   <matplotlib.patches.Wedge at 0x186525754c0>,
#   <matplotlib.patches.Wedge at 0x18652575940>,
#   <matplotlib.patches.Wedge at 0x18652575dc0>,
#   <matplotlib.patches.Wedge at 0x1865257e280>,
#   <matplotlib.patches.Wedge at 0x1865257e700>,
#   <matplotlib.patches.Wedge at 0x1865257eb80>,
#   <matplotlib.patches.Wedge at 0x1865257efa0>,
#   <matplotlib.patches.Wedge at 0x186525894c0>,
#   <matplotlib.patches.Wedge at 0x18652589940>,
#   <matplotlib.patches.Wedge at 0x18652589dc0>,
#   <matplotlib.patches.Wedge at 0x18652592280>,
#   <matplotlib.patches.Wedge at 0x18652592700>,
#   <matplotlib.patches.Wedge at 0x18652592b80>,
#   <matplotlib.patches.Wedge at 0x18652592fa0>,
#   <matplotlib.patches.Wedge at 0x1865259e4c0>,
#   <matplotlib.patches.Wedge at 0x1865259e940>,
#   <matplotlib.patches.Wedge at 0x1865259edc0>,
#   <matplotlib.patches.Wedge at 0x186525a8280>,
#   <matplotlib.patches.Wedge at 0x186525a8700>,
#   <matplotlib.patches.Wedge at 0x186525a8b80>,
#   <matplotlib.patches.Wedge at 0x186525a8fa0>,
#   <matplotlib.patches.Wedge at 0x186525b34c0>,
#   <matplotlib.patches.Wedge at 0x186525b3940>,
#   <matplotlib.patches.Wedge at 0x186525b3dc0>,
#   <matplotlib.patches.Wedge at 0x186525bc280>,
#   <matplotlib.patches.Wedge at 0x186525bc700>,
#   <matplotlib.patches.Wedge at 0x186525bcb80>,
#   <matplotlib.patches.Wedge at 0x186525bcfa0>,
#   <matplotlib.patches.Wedge at 0x186525c74c0>,
#   <matplotlib.patches.Wedge at 0x186525c7940>,
#   <matplotlib.patches.Wedge at 0x186525c7dc0>,
#   <matplotlib.patches.Wedge at 0x186525d1280>,
#   <matplotlib.patches.Wedge at 0x186525d1700>,
#   <matplotlib.patches.Wedge at 0x186525d1b80>,
#   <matplotlib.patches.Wedge at 0x186525d1fa0>,
#   <matplotlib.patches.Wedge at 0x186525dc4c0>,
#   <matplotlib.patches.Wedge at 0x186525dc940>,
#   <matplotlib.patches.Wedge at 0x186525dcdc0>,
#   <matplotlib.patches.Wedge at 0x186525e6280>,
#   <matplotlib.patches.Wedge at 0x186525e6700>,
#   <matplotlib.patches.Wedge at 0x186525e6b80>,
#   <matplotlib.patches.Wedge at 0x186525e6fa0>,
#   <matplotlib.patches.Wedge at 0x186525f14c0>,
#   <matplotlib.patches.Wedge at 0x186525f1940>,
#   <matplotlib.patches.Wedge at 0x186525f1dc0>,
#   <matplotlib.patches.Wedge at 0x186525fa280>,
#   <matplotlib.patches.Wedge at 0x186525fa700>,
#   <matplotlib.patches.Wedge at 0x186525fab80>,
#   <matplotlib.patches.Wedge at 0x186525fafa0>,
#   <matplotlib.patches.Wedge at 0x186526054c0>,
#   <matplotlib.patches.Wedge at 0x18652605940>,
#   <matplotlib.patches.Wedge at 0x18652605dc0>,
#   <matplotlib.patches.Wedge at 0x1865260f280>,
#   <matplotlib.patches.Wedge at 0x1865260f700>,
#   <matplotlib.patches.Wedge at 0x1865260fb80>,
#   <matplotlib.patches.Wedge at 0x1865260ffa0>,
#   <matplotlib.patches.Wedge at 0x1865261a4c0>,
#   <matplotlib.patches.Wedge at 0x1865261a940>,
#   <matplotlib.patches.Wedge at 0x1865261adc0>,
#   <matplotlib.patches.Wedge at 0x18652624280>,
#   <matplotlib.patches.Wedge at 0x18652624700>,
#   <matplotlib.patches.Wedge at 0x18652624b80>,
#   <matplotlib.patches.Wedge at 0x18652624fa0>,
#   <matplotlib.patches.Wedge at 0x1865262f4c0>,
#   <matplotlib.patches.Wedge at 0x1865262f940>,
#   <matplotlib.patches.Wedge at 0x1865262fdc0>,
#   <matplotlib.patches.Wedge at 0x18652638280>,
#   <matplotlib.patches.Wedge at 0x18652638700>,
#   <matplotlib.patches.Wedge at 0x18652638b80>,
#   <matplotlib.patches.Wedge at 0x18652638fa0>,
#   <matplotlib.patches.Wedge at 0x186526434c0>,
#   <matplotlib.patches.Wedge at 0x18652643940>,
#   <matplotlib.patches.Wedge at 0x18652643dc0>,
#   <matplotlib.patches.Wedge at 0x1865264d280>,
#   <matplotlib.patches.Wedge at 0x1865264d700>,
#   <matplotlib.patches.Wedge at 0x1865264db80>,
#   <matplotlib.patches.Wedge at 0x1865264dfa0>,
#   <matplotlib.patches.Wedge at 0x186526574c0>,
#   <matplotlib.patches.Wedge at 0x18652657940>,
#   <matplotlib.patches.Wedge at 0x18652657dc0>,
#   <matplotlib.patches.Wedge at 0x18652661280>,
#   <matplotlib.patches.Wedge at 0x18652661700>,
#   <matplotlib.patches.Wedge at 0x18652661b80>,
#   <matplotlib.patches.Wedge at 0x18652661fa0>,
#   <matplotlib.patches.Wedge at 0x1865266b4c0>,
#   <matplotlib.patches.Wedge at 0x1865266b940>,
#   <matplotlib.patches.Wedge at 0x1865266bdc0>,
#   <matplotlib.patches.Wedge at 0x18652675280>,
#   <matplotlib.patches.Wedge at 0x18652675700>,
#   <matplotlib.patches.Wedge at 0x18652675b80>,
#   <matplotlib.patches.Wedge at 0x18652675fa0>,
#   <matplotlib.patches.Wedge at 0x186526814c0>,
#   <matplotlib.patches.Wedge at 0x18652681940>,
#   <matplotlib.patches.Wedge at 0x18652681dc0>,
#   <matplotlib.patches.Wedge at 0x1865268a280>,
#   <matplotlib.patches.Wedge at 0x1865268a700>,
#   <matplotlib.patches.Wedge at 0x1865268ab80>,
#   <matplotlib.patches.Wedge at 0x1865268afa0>,
#   <matplotlib.patches.Wedge at 0x186526954c0>,
#   <matplotlib.patches.Wedge at 0x18652695940>,
#   <matplotlib.patches.Wedge at 0x18652695dc0>,
#   <matplotlib.patches.Wedge at 0x1865269e280>,
#   <matplotlib.patches.Wedge at 0x1865269e700>,
#   <matplotlib.patches.Wedge at 0x1865269eb80>,
#   <matplotlib.patches.Wedge at 0x1865269efa0>,
#   <matplotlib.patches.Wedge at 0x186526ab4c0>,
#   <matplotlib.patches.Wedge at 0x186526ab940>,
#   <matplotlib.patches.Wedge at 0x186526abdc0>,
#   <matplotlib.patches.Wedge at 0x186526b3280>,
#   <matplotlib.patches.Wedge at 0x186526b3700>,
#   <matplotlib.patches.Wedge at 0x186526b3b80>,
#   <matplotlib.patches.Wedge at 0x186526b3fa0>,
#   <matplotlib.patches.Wedge at 0x186526bf4c0>,
#   <matplotlib.patches.Wedge at 0x186526bf940>,
#   <matplotlib.patches.Wedge at 0x186526bfdc0>,
#   <matplotlib.patches.Wedge at 0x186526ca280>,
#   <matplotlib.patches.Wedge at 0x186526ca700>,
#   <matplotlib.patches.Wedge at 0x186526cab80>,
#   <matplotlib.patches.Wedge at 0x186526cafa0>,
#   <matplotlib.patches.Wedge at 0x186526d54c0>,
#   <matplotlib.patches.Wedge at 0x186526d5940>,
#   <matplotlib.patches.Wedge at 0x186526d5dc0>,
#   <matplotlib.patches.Wedge at 0x186526de280>,
#   <matplotlib.patches.Wedge at 0x186526de700>,
#   <matplotlib.patches.Wedge at 0x186526deb80>,
#   <matplotlib.patches.Wedge at 0x186526defa0>,
#   <matplotlib.patches.Wedge at 0x186526e94c0>,
#   <matplotlib.patches.Wedge at 0x186526e9940>,
#   <matplotlib.patches.Wedge at 0x186526e9dc0>,
#   <matplotlib.patches.Wedge at 0x186526f2280>,
#   <matplotlib.patches.Wedge at 0x186526f2700>,
#   <matplotlib.patches.Wedge at 0x186526f2b80>,
#   <matplotlib.patches.Wedge at 0x186526f2fa0>,
#   <matplotlib.patches.Wedge at 0x186526fe4c0>,
#   <matplotlib.patches.Wedge at 0x186526fe940>,
#   <matplotlib.patches.Wedge at 0x186526fedc0>,
#   <matplotlib.patches.Wedge at 0x18652707280>,
#   <matplotlib.patches.Wedge at 0x18652707700>,
#   <matplotlib.patches.Wedge at 0x18652707b80>,
#   <matplotlib.patches.Wedge at 0x18652707fa0>,
#   <matplotlib.patches.Wedge at 0x186527124c0>,
#   <matplotlib.patches.Wedge at 0x18652712940>,
#   <matplotlib.patches.Wedge at 0x18652712dc0>,
#   <matplotlib.patches.Wedge at 0x1865271f280>,
#   <matplotlib.patches.Wedge at 0x1865271f700>,
#   <matplotlib.patches.Wedge at 0x1865271fb80>,
#   <matplotlib.patches.Wedge at 0x1865271ffa0>,
#   <matplotlib.patches.Wedge at 0x1865272c4c0>,
#   <matplotlib.patches.Wedge at 0x1865272c940>,
#   <matplotlib.patches.Wedge at 0x1865272cdc0>,
#   <matplotlib.patches.Wedge at 0x18652738280>,
#   <matplotlib.patches.Wedge at 0x18652738700>,
#   <matplotlib.patches.Wedge at 0x18652738b80>,
#   <matplotlib.patches.Wedge at 0x18652738fa0>,
#   <matplotlib.patches.Wedge at 0x186527464c0>,
#   <matplotlib.patches.Wedge at 0x18652746940>,
#   <matplotlib.patches.Wedge at 0x18652746dc0>,
#   <matplotlib.patches.Wedge at 0x18652755280>,
#   <matplotlib.patches.Wedge at 0x18652755700>,
#   <matplotlib.patches.Wedge at 0x18652755b80>,
#   <matplotlib.patches.Wedge at 0x18652755fa0>,
#   <matplotlib.patches.Wedge at 0x186527634c0>,
#   <matplotlib.patches.Wedge at 0x18652763940>,
#   <matplotlib.patches.Wedge at 0x18652763dc0>,
#   <matplotlib.patches.Wedge at 0x1865276d280>,
#   <matplotlib.patches.Wedge at 0x1865276d700>,
#   <matplotlib.patches.Wedge at 0x1865276dbb0>,
#   <matplotlib.patches.Wedge at 0x1865276dfd0>,
#   <matplotlib.patches.Wedge at 0x1865277c4f0>,
#   <matplotlib.patches.Wedge at 0x1865277c970>,
#   <matplotlib.patches.Wedge at 0x1865277cdf0>,
#   <matplotlib.patches.Wedge at 0x1865278a2b0>,
#   <matplotlib.patches.Wedge at 0x1865278a730>,
#   <matplotlib.patches.Wedge at 0x1865278abb0>,
#   <matplotlib.patches.Wedge at 0x1865278afd0>,
#   <matplotlib.patches.Wedge at 0x186527994f0>,
#   <matplotlib.patches.Wedge at 0x18652799970>,
#   <matplotlib.patches.Wedge at 0x18652799df0>,
#   <matplotlib.patches.Wedge at 0x186527a52b0>,
#   <matplotlib.patches.Wedge at 0x186527a5730>,
#   <matplotlib.patches.Wedge at 0x186527a5bb0>,
#   <matplotlib.patches.Wedge at 0x186527a5fd0>,
#   <matplotlib.patches.Wedge at 0x186527b44f0>,
#   <matplotlib.patches.Wedge at 0x186527b4970>,
#   <matplotlib.patches.Wedge at 0x186527b4df0>,
#   <matplotlib.patches.Wedge at 0x186527c02b0>,
#   <matplotlib.patches.Wedge at 0x186527c0730>,
#   <matplotlib.patches.Wedge at 0x186527c0bb0>,
#   <matplotlib.patches.Wedge at 0x186527c0fd0>,
#   <matplotlib.patches.Wedge at 0x186527cf4f0>,
#   <matplotlib.patches.Wedge at 0x186527cf970>,
#   <matplotlib.patches.Wedge at 0x186527cfdf0>,
#   <matplotlib.patches.Wedge at 0x186527db2b0>,
#   <matplotlib.patches.Wedge at 0x186527db730>,
#   <matplotlib.patches.Wedge at 0x186527dbbb0>,
#   <matplotlib.patches.Wedge at 0x186527dbfd0>,
#   <matplotlib.patches.Wedge at 0x186527ea4f0>,
#   <matplotlib.patches.Wedge at 0x186527ea970>,
#   <matplotlib.patches.Wedge at 0x186527eadf0>,
#   <matplotlib.patches.Wedge at 0x186527f62b0>,
#   <matplotlib.patches.Wedge at 0x186527f6730>,
#   <matplotlib.patches.Wedge at 0x186527f6bb0>,
#   <matplotlib.patches.Wedge at 0x186527f6fd0>,
#   <matplotlib.patches.Wedge at 0x186528054f0>,
#   <matplotlib.patches.Wedge at 0x18652805970>,
#   <matplotlib.patches.Wedge at 0x18652805df0>,
#   <matplotlib.patches.Wedge at 0x186528112b0>,
#   <matplotlib.patches.Wedge at 0x18652811730>,
#   <matplotlib.patches.Wedge at 0x18652811bb0>,
#   <matplotlib.patches.Wedge at 0x18652811fd0>,
#   <matplotlib.patches.Wedge at 0x1865281f4f0>,
#   <matplotlib.patches.Wedge at 0x1865281f970>],
#  [Text(1.099986387402452, 0.005472433581417054, ''),
#   Text(1.0999063563221827, 0.014352955168174945, ''),
#   Text(1.0997570250229194, 0.023118951376270416, ''),
#   Text(1.0995189825039504, 0.0325270212819738, ''),
#   Text(1.0992627196339928, 0.040267520694452226, ''),
#   Text(1.0988461216583034, 0.05037063545862193, ''),
#   Text(1.0982926630593366, 0.06126358029066641, ''),
#   Text(1.0977911390319728, 0.06967506772787514, ''),
#   Text(1.0972653728847461, 0.07751581430972124, ''),
#   Text(1.0965710016934582, 0.08678731615279893, ''),
#   Text(1.0957916744912755, 0.0961280714235281, ''),
#   Text(1.0951483019213404, 0.10319979069167322, ''),
#   Text(1.0944725716264614, 0.1101353256560335, ''),
#   Text(1.0936110592730508, 0.11838433610776465, ''),
#   Text(1.092672108730567, 0.12675828494538682, ''),
#   Text(1.0915780749020072, 0.13585766961503598, ''),
#   Text(1.0904456573608272, 0.144666058019543, ''),
#   Text(1.0894315359664637, 0.15211485279798254, ''),
#   Text(1.0882232699423466, 0.1605307283855235, ''),
#   Text(1.0867573528394798, 0.1701718427041519, ''),
#   Text(1.0852833000097686, 0.17933253670181204, ''),
#   Text(1.0840002232183892, 0.18693184871092164, ''),
#   Text(1.0827375266640578, 0.19411194799238685, ''),
#   Text(1.0810651816449885, 0.20321927328599482, ''),
#   Text(1.079265033883275, 0.21257230919603165, ''),
#   Text(1.0776847546312018, 0.2204440283507056, ''),
#   Text(1.0758698850602342, 0.2291374923937127, ''),
#   Text(1.073676953816324, 0.2392024223198826, ''),
#   Text(1.0704905496216315, 0.2530809814481868, ''),
#   Text(1.0675644014602184, 0.2651532551844045, ''),
#   Text(1.0642631362828714, 0.2781078509307972, ''),
#   Text(1.0609098124454148, 0.29063786721113083, ''),
#   Text(1.0589295619162415, 0.29777203176234807, ''),
#   Text(1.0568750911083815, 0.30498367463628323, ''),
#   Text(1.0549754940712173, 0.3114911024558988, ''),
#   Text(1.0525859169698937, 0.31947282732127363, ''),
#   Text(1.0494573186703713, 0.32960481836465194, ''),
#   Text(1.0462545830319256, 0.3396341376903849, ''),
#   Text(1.0437298441920815, 0.3473154363727211, ''),
#   Text(1.041289177529488, 0.3545657185346081, ''),
#   Text(1.0384676231352623, 0.36274646200865807, ''),
#   Text(1.0351533220011226, 0.37209891151418356, ''),
#   Text(1.0315313761239544, 0.3820248945707871, ''),
#   Text(1.0280501975925855, 0.39129629595722704, ''),
#   Text(1.0250981406834698, 0.39896591579644186, ''),
#   Text(1.0216753629347126, 0.40765114101670713, ''),
#   Text(1.0178346622325785, 0.4171481755418489, ''),
#   Text(1.0146531894517692, 0.4248280889199214, ''),
#   Text(1.0105406605634635, 0.4345199343504956, ''),
#   Text(1.0057765953903717, 0.44543623580143626, ''),
#   Text(1.0017333911307575, 0.45445595286416135, ''),
#   Text(0.998278394658155, 0.46199593803272454, ''),
#   Text(0.9948393751685046, 0.46935553433867117, ''),
#   Text(0.9910176276502126, 0.4773720369759258, ''),
#   Text(0.9874986265282297, 0.48460959813530313, ''),
#   Text(0.9843581765718025, 0.4909572081314586, ''),
#   Text(0.9804053069519901, 0.4988040036932084, ''),
#   Text(0.9762241339918464, 0.5069383002021745, ''),
#   Text(0.9711318982120162, 0.5166263991271899, ''),
#   Text(0.9647724893552757, 0.5284070815036686, ''),
#   Text(0.9593097333575228, 0.5382609362433045, ''),
#   Text(0.954575477551605, 0.5466128956191261, ''),
#   Text(0.9500454186209041, 0.5544490080768756, ''),
#   Text(0.9452283490754025, 0.5626218695573334, ''),
#   Text(0.9405570597725129, 0.5703967192332771, ''),
#   Text(0.9359909683773846, 0.57785889896753, ''),
#   Text(0.9304072745620814, 0.5868068706499266, ''),
#   Text(0.9250967860934822, 0.5951436266646146, ''),
#   Text(0.9202410189549749, 0.602624648543942, ''),
#   Text(0.9133561582113806, 0.6130094030741678, ''),
#   Text(0.9061501944090286, 0.6236119187222772, ''),
#   Text(0.9009664703743536, 0.6310779819175909, ''),
#   Text(0.8966326048383072, 0.637220504959525, ''),
#   Text(0.8922236371484356, 0.6433793447987098, ''),
#   Text(0.8868098376819038, 0.6508212594795868, ''),
#   Text(0.881956767824493, 0.657382886671515, ''),
#   Text(0.8740633945954137, 0.6678421836245014, ''),
#   Text(0.8659992877341751, 0.6782663441774932, ''),
#   Text(0.8628726742162722, 0.6822395093300145, ''),
#   Text(0.8592669513773052, 0.6867752953264641, ''),
#   Text(0.8535270866332242, 0.6938958944851892, ''),
#   Text(0.8473419517603261, 0.7014353974437001, ''),
#   Text(0.8417488522321324, 0.7081376065185975, ''),
#   Text(0.8366193233116425, 0.7141905263034295, ''),
#   Text(0.831570236211814, 0.7200631515684078, ''),
#   Text(0.8271917974596784, 0.7250887740238614, ''),
#   Text(0.8221542811605228, 0.7307956882531698, ''),
#   Text(0.8161004812627543, 0.7375500013441131, ''),
#   Text(0.8096323669861867, 0.7446444992936864, ''),
#   Text(0.8029343443978199, 0.7518619810752792, ''),
#   Text(0.797255653496752, 0.7578808765020181, ''),
#   Text(0.7905054840655801, 0.764919002027171, ''),
# ...
#   Text(-0.889502241998207, -0.6471365864175532, ''),
#   Text(-0.8846539284424302, -0.6537487490553048, ''),
#   Text(-0.8790512037400225, -0.66126317091096, ''),
#   Text(-0.8729585390940241, -0.669285730479014, ''),
#   Text(-0.8648304122113207, -0.6797561019324484, ''),
#   Text(-0.8572771957459121, -0.6892574335137961, ''),
#   Text(-0.8517924065333008, -0.6960242065993167, ''),
#   Text(-0.8462421087395854, -0.7027619037739452, ''),
#   Text(-0.8405408063434742, -0.7095711048735444, ''),
#   Text(-0.8339456187421188, -0.7173107450615981, ''),
#   Text(-0.8283391027653407, -0.7237778186915585, ''),
#   Text(-0.8225818698126472, -0.730314362076722, ''),
#   Text(-0.8160877874029064, -0.7375640468812377, ''),
#   Text(-0.8108106656513938, -0.743361328336324, ''),
#   Text(-0.8055439432817367, -0.749065387961632, ''),
#   Text(-0.8000031946124182, -0.7549800584187145, ''),
#   Text(-0.7938162785224802, -0.7614825775766116, ''),
#   Text(-0.7865976272402695, -0.7689370408687424, ''),
#   Text(-0.7798567034787965, -0.7757728546676435, ''),
#   Text(-0.7732584173470322, -0.7823499344934869, ''),
#   Text(-0.7656399163841464, -0.7898072666412215, ''),
#   Text(-0.7585668143137675, -0.7966030305126026, ''),
#   Text(-0.7511567728361186, -0.8035941155971886, ''),
#   Text(-0.7438636675789272, -0.8103498281952229, ''),
#   Text(-0.7369316529063109, -0.8166588877522687, ''),
#   Text(-0.7299602961313661, -0.8228960846132448, ''),
#   Text(-0.7234640689259548, -0.8286131431332123, ''),
#   Text(-0.7171241088720207, -0.8341061158356953, ''),
#   Text(-0.7093251026815849, -0.8407484158211417, ''),
#   Text(-0.7016833435709924, -0.8471366391291507, ''),
#   Text(-0.695011970642979, -0.8526185317379413, ''),
#   Text(-0.6881943715687341, -0.8581308215774069, ''),
#   Text(-0.6810803012997679, -0.8637879503566934, ''),
#   Text(-0.674323738211724, -0.869072779509384, ''),
#   Text(-0.6682934941489967, -0.8737183789288887, ''),
#   Text(-0.6615809142238763, -0.8788120925059578, ''),
#   Text(-0.6550272903809768, -0.8837076716064852, ''),
#   Text(-0.6482844725086796, -0.888665990518453, ''),
#   Text(-0.6416886976778944, -0.8934403255240095, ''),
#   Text(-0.6352896629275154, -0.8980016949747054, ''),
#   Text(-0.6286406791822771, -0.9026687634327698, ''),
#   Text(-0.6230346408175438, -0.906547205798658, ''),
#   Text(-0.6176240624578586, -0.9102420103868264, ''),
#   Text(-0.6106646861572181, -0.9149254838950036, ''),
#   Text(-0.6032264977850675, -0.9198466135013827, ''),
#   Text(-0.5946498728234519, -0.9254142471083167, ''),
#   Text(-0.586342327227364, -0.9307000995495806, ''),
#   Text(-0.5763435713987407, -0.9369248036568062, ''),
#   Text(-0.5664410703197932, -0.9429445974472559, ''),
#   Text(-0.5594620647808697, -0.9471019998242671, ''),
#   Text(-0.5524034233646792, -0.9512362786684406, ''),
#   Text(-0.5464321334070557, -0.9546789636208677, ''),
#   Text(-0.5407692135591176, -0.9578980413732213, ''),
#   Text(-0.5337135936905656, -0.9618470771956954, ''),
#   Text(-0.5249159659887348, -0.9666763825862891, ''),
#   Text(-0.5181303530581204, -0.970330323776325, ''),
#   Text(-0.5109168854977783, -0.974147799932459, ''),
#   Text(-0.5019911321657413, -0.9787772490342006, ''),
#   Text(-0.4941234036043893, -0.9827726400396045, ''),
#   Text(-0.4861049755020399, -0.9867633722388369, ''),
#   Text(-0.47744027959418966, -0.9909847523655558, ''),
#   Text(-0.468259218421024, -0.9953558682017863, ''),
#   Text(-0.45829806330247086, -0.9999814424144103, ''),
#   Text(-0.44861974608214683, -1.0043606540606766, ''),
#   Text(-0.44021881957288367, -1.0080711239262123, ''),
#   Text(-0.4314736987720987, -1.0118450707830347, ''),
#   Text(-0.42075496013750896, -1.0163489870707223, ''),
#   Text(-0.41025277392829346, -1.0206334608879628, ''),
#   Text(-0.4024752160035811, -1.023725402880514, ''),
#   Text(-0.39506317957722, -1.0266085350036485, ''),
#   Text(-0.38564500353701836, -1.0301834454343233, ''),
#   Text(-0.37646138177204275, -1.033574781055674, ''),
#   Text(-0.3692107091891961, -1.0361869774418182, ''),
#   Text(-0.36192403138150897, -1.038754540547745, ''),
#   Text(-0.35395620862098487, -1.0414965205792375, ''),
#   Text(-0.3458058370237712, -1.0442309720939564, ''),
#   Text(-0.3383190992946343, -1.0466805563554085, ''),
#   Text(-0.32987580000655625, -1.0493721725727412, ''),
#   Text(-0.3211213268518042, -1.0520841665194554, ''),
#   Text(-0.31359713454100835, -1.0543513822287467, ''),
#   Text(-0.30551125275847363, -1.0567227046098462, ''),
#   Text(-0.297279826995166, -1.0590678469586943, ''),
#   Text(-0.2885553418446812, -1.0614781272795495, ''),
#   Text(-0.27801625202401364, -1.0642870682341867, ''),
#   Text(-0.26794572546887274, -1.0668669496253784, ''),
#   Text(-0.25941569098788314, -1.0689731050261644, ''),
#   Text(-0.24926482277173073, -1.071385573978191, ''),
#   Text(-0.23825971679348693, -1.0738865430544735, ''),
#   Text(-0.22952641110906577, -1.0757869801235709, ''),
#   Text(-0.22177958463895212, -1.07741069970433, ''),
#   Text(-0.21273952089691228, -1.0792320863690776, ''),
#   Text(-0.20200950819054553, -1.0812918933389883, ''),
#   Text(-0.19202406180716872, -1.083109763452937, ''),
#   Text(-0.18181684114849805, -1.0848698706641189, ''),
#   Text(-0.1714064566416777, -1.0865633099923562, ''),
#   Text(-0.16420150086381902, -1.0876754419927248, ''),
#   Text(-0.15712052569000154, -1.0887208735056464, ''),
#   Text(-0.14763139956483035, -1.0900481502495794, ''),
#   Text(-0.13715414797797787, -1.0914159334059748, ''),
#   Text(-0.12694638555117374, -1.0926502712192465, ''),
#   Text(-0.11700996134331516, -1.0937589629102182, ''),
#   Text(-0.10766692411118442, -1.094718152518006, ''),
#   Text(-0.09861779454064001, -1.095570413346372, ''),
#   Text(-0.0904111881841599, -1.0962781659100616, ''),
#   Text(-0.0840499176639705, -1.0967842136631434, ''),
#   Text(-0.07485227960600084, -1.0974502887319249, ''),
#   Text(-0.06423167035892825, -1.0981230771288353, ''),
#   Text(-0.054021139177324276, -1.0986727067338955, ''),
#   Text(-0.04250037323880553, -1.0991786562131574, ''),
#   Text(-0.031164218924985554, -1.0995584529522728, ''),
#   Text(-0.02044952911753928, -1.0998099002822583, ''),
#   Text(-0.010603909169422382, -1.099948888408151, ''),
#   Text(-0.0004355304319262343, -1.0999999137787435, ''),
#   Text(0.009297377612584461, -1.099960707829843, ''),
#   Text(0.01893489279201458, -1.0998370196692577, ''),
#   Text(0.027851629132559508, -1.0996473465410002, ''),
#   Text(0.036823310268507964, -1.0993834835128593, ''),
#   Text(0.04741955904182389, -1.0989774271659447, ''),
#   Text(0.05941065538100827, -1.0983944528388694, ''),
#   Text(0.07137577950474792, -1.0976818747251362, ''),
#   Text(0.08032997481175955, -1.09706294037614, ''),
#   Text(0.08916558113085932, -1.0963801800204145, ''),
#   Text(0.09790109725040942, -1.0956346905593881, ''),
#   Text(0.10538644628028246, -1.094940042623528, ''),
#   Text(0.11350727415647505, -1.0941280083763356, ''),
#   Text(0.12290151211031938, -1.0931126283787034, ''),
#   Text(0.1319483037371047, -1.092057528311078, ''),
#   Text(0.14017848513136752, -1.0910316183806383, ''),
#   Text(0.14903860440678832, -1.0898566393780775, ''),
#   Text(0.15800132213004855, -1.0885933961792882, ''),
#   Text(0.16566178859080796, -1.087453986061431, ''),
#   Text(0.17415546023318831, -1.0861260864517372, ''),
#   Text(0.18398281021829468, -1.0845046452386358, ''),
#   Text(0.19254609092019823, -1.0830170833700412, ''),
#   Text(0.2003153963157499, -1.0816070182829178, ''),
#   Text(0.20811156732244165, -1.080134054433336, ''),
#   Text(0.21708510183173915, -1.0783663841954199, ''),
#   Text(0.22643278025669122, -1.0764423793335272, ''),
#   Text(0.234690541502169, -1.0746722057117783, ''),
#   Text(0.2438577919149374, -1.0726291891060822, ''),
#   Text(0.2542786274348011, -1.070206699488409, ''),
#   Text(0.2637011847765707, -1.0679240071968759, ''),
#   Text(0.2709932852447726, -1.0660969183672961, ''),
#   Text(0.2781628080405406, -1.0642487736535107, ''),
#   Text(0.2871663598814733, -1.0618547366530058, ''),
#   Text(0.29662343640255123, -1.0592518760789342, ''),
#   Text(0.3051656005152223, -1.056822575583141, ''),
#   Text(0.31399640236216353, -1.0542325451737953, ''),
#   Text(0.32432546686439045, -1.0511008474657393, ''),
#   Text(0.3344248772864104, -1.0479312961506444, ''),
#   Text(0.3427124774053535, -1.0452502847790501, ''),
#   Text(0.35027861194343596, -1.042739130374889, ''),
#   Text(0.3596879933185649, -1.0395309266503159, ''),
#   Text(0.36863984827650403, -1.0363902075293245, ''),
#   Text(0.37614109120451794, -1.0336913850407552, ''),
#   Text(0.3842968810306103, -1.030687104426045, ''),
#   Text(0.39271170108736636, -1.0275103502296545, ''),
#   Text(0.4016468022355746, -1.0240507049233145, ''),
#   Text(0.4108149284469365, -1.0204073179692208, ''),
#   Text(0.41905726855321007, -1.017050149045131, ''),
#   Text(0.4284235328313201, -1.0131403044575469, ''),
#   Text(0.4385001908276214, -1.0088198960390005, ''),
#   Text(0.4463190638726253, -1.005385146709391, ''),
#   Text(0.4538005689943006, -1.0020304604054955, ''),
#   Text(0.46271757130383023, -0.9979441112640952, ''),
#   Text(0.47156356625751356, -0.9937946482943525, ''),
#   Text(0.4798953246672339, -0.9897982003229397, ''),
#   Text(0.4892958818295648, -0.9851850283193654, ''),
#   Text(0.4979261899678309, -0.9808514206260395, ''),
#   Text(0.5045504565927611, -0.9774604016286473, ''),
#   Text(0.5125427897993595, -0.9732933209596631, ''),
#   Text(0.5224347594046125, -0.9680195876974003, ''),
#   Text(0.5312281637814544, -0.9632220086799224, ''),
#   Text(0.539251478306215, -0.9587532754283355, ''),
#   Text(0.5466621854173817, -0.9545472513368274, ''),
#   Text(0.5538110526977352, -0.9504174440264797, ''),
#   Text(0.5643944686063119, -0.944171003476912, ''),
#   Text(0.5738092690906306, -0.9384790475581629, ''),
#   Text(0.5808528538053831, -0.9341359441891434, ''),
#   Text(0.5890474537925614, -0.9289903644174683, ''),
#   Text(0.5979913623665822, -0.9232585393783038, ''),
#   Text(0.6058999780981897, -0.9180878043741859, ''),
#   Text(0.6124747149290117, -0.913714793342335, ''),
#   Text(0.622300960454568, -0.9070509989065237, ''),
#   Text(0.6326125091683724, -0.8998896672613238, ''),
#   Text(0.6404576763472626, -0.894323188119298, ''),
#   Text(0.6467996675207507, -0.889747261920511, ''),
#   Text(0.6541750756927751, -0.8843387192373475, ''),
#   Text(0.663138069047266, -0.8776376822927919, ''),
#   Text(0.6712226166227537, -0.8714701365704415, ''),
#   Text(0.6787730830994808, -0.8656021613071594, ''),
#   Text(0.6861686571571364, -0.8597514605600693, ''),
#   Text(0.6929845313467713, -0.8542671943333044, ''),
#   Text(0.6996250721644274, -0.8488372979546316, ''),
#   Text(0.7075288279135603, -0.8422606233650388, ''),
#   Text(0.7159172233579805, -0.8351422210015488, ''),
#   Text(0.7241769934875393, -0.8279901461390399, ''),
#   Text(0.7320968311578132, -0.8209958768524288, ''),
#   Text(0.739935108952849, -0.8139385938379724, ''),
#   Text(0.748135802002137, -0.8064073547299897, ''),
#   Text(0.7562460936026439, -0.7988065134378545, ''),
#   Text(0.7646740148400435, -0.7907424682084611, ''),
#   Text(0.7722342022321399, -0.7833609237783633, ''),
#   Text(0.7796029171925256, -0.7760278935095725, ''),
#   Text(0.7870343045435076, -0.7684900802689112, ''),
#   Text(0.7941177014626583, -0.7611682312233377, ''),
#   Text(0.8010681028057326, -0.7538500478657705, ''),
#   Text(0.806986643167148, -0.7475109081142686, ''),
#   Text(0.8124849373712347, -0.7415310017422474, ''),
#   Text(0.8178249583878858, -0.7356373681630461, ''),
#   Text(0.8229714741308918, -0.7298752994634269, ''),
#   Text(0.8286754091843497, -0.7233927468624155, ''),
#   Text(0.8346120465061775, -0.7165352272057325, ''),
#   Text(0.8405652281756637, -0.7095421743504713, ''),
#   Text(0.8463751601628254, -0.7026016568862842, ''),
#   Text(0.8519002236865588, -0.6958922394184255, ''),
#   Text(0.857775300539747, -0.68863744727102, ''),
#   Text(0.8627552124141893, -0.6823880446286755, ''),
#   Text(0.8685733929891988, -0.6749668591799386, ''),
#   Text(0.8745000693426694, -0.6672702816098336, ''),
#   Text(0.8789145794622838, -0.6614447535574207, ''),
#   Text(0.8841922921438674, -0.6543729750787192, ''),
#   Text(0.8909482153642301, -0.6451443850327565, ''),
#   Text(0.8978266818129367, -0.635536977228526, ''),
#   Text(0.902928405382087, -0.6282676935464387, ''),
#   Text(0.9082277427415207, -0.620582280857778, ''),
#   Text(0.9138096647811097, -0.6123331581358601, ''),
#   Text(0.9188276545409424, -0.6047774311685173, ''),
#   Text(0.9241530785990036, -0.5966079846230554, ''),
#   Text(0.9291120175996926, -0.5888555499881347, ''),
#   Text(0.9330945404876005, -0.5825243158119957, ''),
#   Text(0.9370636750523652, -0.5761177561031734, ''),
#   Text(0.9411162877846958, -0.5694735576533416, ''),
#   Text(0.9453445472766887, -0.562426605820024, ''),
#   Text(0.9509318356035892, -0.5529273406475651, ''),
#   Text(0.9565826482284422, -0.543092659781239, ''),
#   Text(0.9620950356513462, -0.5332664834536622, ''),
#   Text(0.9674163787449644, -0.5235509050092262, ''),
#   Text(0.9721704529869512, -0.5146694185000177, ''),
#   Text(0.9772257794413034, -0.5050047286861156, ''),
#   Text(0.9820571043380469, -0.4955439877742143, ''),
#   Text(0.9862943041111992, -0.4870559985030526, ''),
#   Text(0.9905899078140246, -0.4782589617947609, ''),
#   Text(0.9942973716598175, -0.4705026426178485, ''),
#   Text(0.9980476298396603, -0.4624942470684758, ''),
#   Text(1.0017568552841292, -0.45440422851383394, ''),
#   Text(1.0049159158630745, -0.4473745657109691, ''),
#   Text(1.0087972425635021, -0.43855230405993184, ''),
#   Text(1.0122753627696366, -0.4304632271514037, ''),
#   Text(1.0151206118192102, -0.42370997564347296, ''),
#   Text(1.0188298960748137, -0.41471151764110037, ''),
#   Text(1.0226757603251369, -0.40513490252433637, ''),
#   Text(1.0267784576441013, -0.3946213361160303, ''),
#   Text(1.0313800361732188, -0.3824332895856873, ''),
#   Text(1.0351597238828614, -0.37208110144262696, ''),
#   Text(1.0388666349852989, -0.3616021497645196, ''),
#   Text(1.0422194174855521, -0.3518219518678111, ''),
#   Text(1.045149942518487, -0.3430183634349676, ''),
#   Text(1.0483507194635349, -0.3331077438311653, ''),
#   Text(1.0511510780814455, -0.32416263055481154, ''),
#   Text(1.053510879062039, -0.3164092724588355, ''),
#   Text(1.0559939537472232, -0.3080207292526069, ''),
#   Text(1.058898797469247, -0.2978814138515241, ''),
#   Text(1.0613538449985902, -0.2890121376459965, ''),
#   Text(1.063696018174398, -0.28026912230913137, ''),
#   Text(1.066078252141076, -0.2710667082321776, ''),
#   Text(1.0680962744107083, -0.26300256384675214, ''),
#   Text(1.0701891844615088, -0.25435233331269225, ''),
#   Text(1.07213162526689, -0.24603613170137698, ''),
#   Text(1.0738331956982954, -0.23850003735091319, ''),
#   Text(1.0755731518885965, -0.23052634325913915, ''),
#   Text(1.077536512450663, -0.22116750289240505, ''),
#   Text(1.0793929119636845, -0.21192201773897368, ''),
#   Text(1.0810091663206696, -0.20351703204078742, ''),
#   Text(1.0824826431057473, -0.19552832882934312, ''),
#   Text(1.0842278842609936, -0.18560682905251463, ''),
#   Text(1.0860510340054603, -0.17462288376862428, ''),
#   Text(1.0873940256828458, -0.16605490931994354, ''),
#   Text(1.0885034618088503, -0.1586197138761413, ''),
#   Text(1.089556853969753, -0.15121462220147328, ''),
#   Text(1.0908692139776506, -0.14143676323991244, ''),
#   Text(1.0921436064804089, -0.13123392405916184, ''),
#   Text(1.0931168574050658, -0.12286389240486065, ''),
#   Text(1.0940180767216556, -0.1145619823774441, ''),
#   Text(1.0948927632179932, -0.10587651794835133, ''),
#   Text(1.0956834265840574, -0.09735414068758833, ''),
#   Text(1.0965620311475421, -0.08690058599098795, ''),
#   Text(1.0972840217535906, -0.0772513793033213, ''),
#   Text(1.0977368353956645, -0.07052545792486441, ''),
#   Text(1.0981790448864686, -0.06326756967233486, ''),
#   Text(1.0985441977851005, -0.056574247787224766, ''),
#   Text(1.0988504526420815, -0.050276065163186584, ''),
#   Text(1.099183039921336, -0.04238684641832404, ''),
#   Text(1.0995099815811649, -0.03282987059656223, ''),
#   Text(1.0997342270054529, -0.024179122248732674, ''),
#   Text(1.0998519792116643, -0.01804504985265687, ''),
#   Text(1.09994403217028, -0.011096219761073015, ''),
#   Text(1.0999950085782395, -0.003313774729675996, '')])

# %%
sns.set(rc = {'figure.figsize':(10,6)})
sns.set_context("talk", font_scale=0.6)
sns.countplot(x=df['FastingBS'],data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='FastingBS', ylabel='count'>

# %%
sns.countplot(x=df['RestingECG'],palette='deep')
# Out:
# <AxesSubplot:xlabel='RestingECG', ylabel='count'>

# %%
df['MaxHR'].mean()
# Out:
# 136.80936819172112

# %%
df['MaxHR'].max()
# Out:
# 202

# %%
df['MaxHR'].min()
# Out:
# 60

# %%
sns.set(rc = {'figure.figsize':(19,10)})
sns.set_context("talk", font_scale=0.6)
sns.countplot(x=df['MaxHR'],data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='MaxHR', ylabel='count'>

# %%
sns.countplot(x=df['ExerciseAngina'],palette='deep')
# Out:
# <AxesSubplot:xlabel='ExerciseAngina', ylabel='count'>

# %%
df['ExerciseAngina'].value_counts()
# Out:
# N    547
# Y    371
# Name: ExerciseAngina, dtype: int64

# %%
sns.set(rc = {'figure.figsize':(19,10)})
sns.set_context("talk", font_scale=0.6)
sns.countplot(x=df['Oldpeak'],data=df,palette='coolwarm')
# Out:
# <AxesSubplot:xlabel='Oldpeak', ylabel='count'>

# %%
df['Oldpeak'].value_counts()
# Out:
#  0.0    368
#  1.0     86
#  2.0     76
#  1.5     53
#  3.0     28
#  1.2     26
#  0.2     22
#  0.5     19
#  1.4     18
#  1.8     17
#  2.5     16
#  0.8     16
#  1.6     16
#  0.1     14
#  0.6     14
#  0.4     11
#  0.3     11
#  4.0      8
#  0.7      7
#  2.8      7
#  1.3      7
#  2.6      7
#  1.1      7
#  1.9      7
#  1.7      6
#  2.2      5
#  0.9      4
#  3.6      4
#  2.4      4
#  3.4      3
#  2.1      2
# -0.1      2
#  4.2      2
#  3.2      2
#  3.5      2
# -0.5      2
#  2.3      2
# -1.0      2
#  2.9      1
#  3.8      1
# -0.9      1
# -2.6      1
# -1.5      1
#  3.7      1
#  5.0      1
# -2.0      1
# -0.8      1
#  3.1      1
#  4.4      1
#  5.6      1
#  6.2      1
# -0.7      1
# -1.1      1
# Name: Oldpeak, dtype: int64

# %%
sns.countplot(x=df['ST_Slope'],palette='deep')
# Out:
# <AxesSubplot:xlabel='ST_Slope', ylabel='count'>

# %%
df['ST_Slope'].value_counts()
# Out:
# Flat    460
# Up      395
# Down     63
# Name: ST_Slope, dtype: int64

# %%
sns.countplot(x=df['HeartDisease'],palette='deep')
# Out:
# <AxesSubplot:xlabel='HeartDisease', ylabel='count'>

# %%
df['HeartDisease'].value_counts()
# Out:
# 1    508
# 0    410
# Name: HeartDisease, dtype: int64
